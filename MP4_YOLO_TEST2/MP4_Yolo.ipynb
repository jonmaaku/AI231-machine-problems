# %%
# Copilot prompt:
# Write code to install and import all necessary libraries for training a YOLO model using Ultralytics in Google Colab.
# Include: ultralytics, torch, matplotlib, gradio.

# Install required packages

# Import necessary libraries
import torch
import torchvision
import matplotlib.pyplot as plt
import gradio as gr
from ultralytics import YOLO
import cv2
import numpy as np
import os
import yaml
from PIL import Image
import random
from pathlib import Path
import ultralytics

print("All libraries installed and imported successfully!")
print(f"Ultralytics version: {ultralytics.__version__ if 'ultralytics' in globals() else 'Not available'}")
print(f"PyTorch version: {torch.__version__}")
print(f"Matplotlib version: {plt.matplotlib.__version__}")
print(f"OpenCV version: {cv2.__version__}")
# Out:
# All libraries installed and imported successfully!
# Ultralytics version: 8.3.207
# PyTorch version: 2.8.0+cu128
# Matplotlib version: 3.10.3
# OpenCV version: 4.12.0

# %%
# Copilot prompt:
# Add code to check if GPU is available and print device information (CUDA, GPU name, etc).

# Check GPU availability and print device information
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device: {device}")

if torch.cuda.is_available():
    print(f"GPU is available: {torch.cuda.get_device_name(0)}")
    print(f"CUDA version: {torch.version.cuda}")
    print(f"Number of GPUs: {torch.cuda.device_count()}")
    print(f"Current GPU: {torch.cuda.current_device()}")
    print(f"GPU memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
else:
    print("GPU is not available, using CPU")
    
print(f"PyTorch version: {torch.__version__}")
print(f"TorchVision version: {torchvision.__version__}")
# Out:
# Device: cuda
# GPU is available: NVIDIA GeForce RTX 4050 Laptop GPU
# CUDA version: 12.8
# Number of GPUs: 1
# Current GPU: 0
# GPU memory: 6.00 GB
# PyTorch version: 2.8.0+cu128
# TorchVision version: 0.23.0+cu128

# %%
class_labels = {
    0: "coffee_nescafe",
    1: "coffee_kopiko",
    2: "lucky-me-pancit-canton",
    3: "Coke-in-can",
    4: "alaska_milk",
    5: "Century-Tuna",
    6: "VCut-Spicy-Barbeque",
    7: "Selecta-Cornetto",
    8: "nestleyogurt",
    9: "Femme-Bathroom-Tissue",
    10: "maya-champorado",
    11: "jnj-potato-chips",
    12: "Nivea-Deodorant",
    13: "UFC-Canned-Mushroom",
    14: "Libbys-Vienna-Sausage-can",
    15: "Stik-O",
    16: "nissin_cup_noodles",
    17: "dewberry-strawberry",
    18: "Smart-C",
    19: "pineapple-juice-can",
    20: "nestle_chuckie",
    21: "Delight-Probiotic-Drink",
    22: "Summit-Drinking-Water",
    23: "almond_milk",
    24: "Piknik",
    25: "Rambutan",
    26: "head&shoulders_shampoo",
    27: "irish-spring-soap",
    28: "c2_na_green",
    29: "colgate_toothpaste",
    30: "555-sardines-tomato",
    31: "meadows_truffle_chips",
    32: "double-black",
    33: "NongshimCupNoodles"
}

class_names = [name for name in class_labels.values()]
dataset_path = ".././data/mp4/dataset"

# %%
# Copilot prompt:
# Write code to preview random images from the training dataset with their YOLO bounding boxes drawn on top.

def draw_yolo_bboxes(image_path, label_path, class_names):
    """Draw YOLO bounding boxes on image"""
    # Load image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    h, w, _ = image.shape
    
    # Load labels if they exist
    if os.path.exists(label_path):
        with open(label_path, 'r') as f:
            for line in f:
                if line.strip():
                    parts = line.strip().split()
                    class_id = int(parts[0])
                    x_center, y_center, width, height = map(float, parts[1:5])
                    
                    # Convert YOLO format to pixel coordinates
                    x_center *= w
                    y_center *= h
                    width *= w
                    height *= h
                    
                    x1 = int(x_center - width/2)
                    y1 = int(y_center - height/2)
                    x2 = int(x_center + width/2)
                    y2 = int(y_center + height/2)
                    
                    # Draw bounding box
                    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    
                    # Draw class label
                    class_name = class_names[class_id] if class_id < len(class_names) else f'class_{class_id}'
                    cv2.putText(image, class_name, (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    
    return image
# Preview random training images with bounding boxes
train_images_path = f"{dataset_path}/train/images"
train_labels_path = f"{dataset_path}/train/labels"

if os.path.exists(train_images_path) and os.listdir(train_images_path):
    image_files = [f for f in os.listdir(train_images_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    
    if image_files:
        # Select random images to display
        num_images = min(4, len(image_files))
        random_images = random.sample(image_files, num_images)
        
        fig, axes = plt.subplots(2, 2, figsize=(12, 10))
        axes = axes.flatten()
        
        for i, img_file in enumerate(random_images):
            img_path = os.path.join(train_images_path, img_file)
            label_path = os.path.join(train_labels_path, img_file.rsplit('.', 1)[0] + '.txt')
            
            image_with_boxes = draw_yolo_bboxes(img_path, label_path, class_names)
            
            axes[i].imshow(image_with_boxes)
            axes[i].set_title(f'Training Image: {img_file}')
            axes[i].axis('off')
        
        plt.tight_layout()
        plt.show()
    else:
        print("No image files found in training directory.")
else:
    print("Training images directory not found or empty.")
    print("Please add images and labels to the training directory to preview them.")

# %%
# Copilot prompt:
# Load the latest YOLO model (e.g., yolov11n.pt if available, otherwise yolov8n.pt) using the Ultralytics library.
# Show the model summary.

# Try to load the latest YOLO model

try:
    # Try YOLOv11n first (latest)
    model = YOLO("yolo11n.pt")
    print("Loaded YOLOv11n model successfully!")
except:
    try:
        # Fallback to YOLOv8n
        model = YOLO('yolov8n.pt')
        print("Loaded YOLOv8n model successfully!")
    except:
        print("Error loading YOLO model. Please check your internet connection.")
        model = None

if model is not None:
    # Show model information
    print(f"\nModel architecture: {model.model}")
    print(f"Model task: {model.task}")
    
    # Print model summary
    model.info(detailed=True)
    
    print(f"\nModel loaded successfully and ready for training!")
else:
    print("Failed to load YOLO model.")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 3.4MB/s 1.6s.6s<0.0s2.8s
# Loaded YOLOv11n model successfully!
#
# Model architecture: DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C3k2(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(8, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (3): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (4): C3k2(
#       (cv1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (5): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (6): C3k2(
#       (cv1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): C3k(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     (7): Conv(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (8): C3k2(
#       (cv1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): C3k(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     (9): SPPF(
#       (cv1): Conv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#     )
#     (10): C2PSA(
#       (cv1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): PSABlock(
#           (attn): Attention(
#             (qkv): Conv(
#               (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): Identity()
#             )
#             (proj): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): Identity()
#             )
#             (pe): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): Identity()
#             )
#           )
#           (ffn): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): Identity()
#             )
#           )
#         )
#       )
#     )
#     (11): Upsample(scale_factor=2.0, mode='nearest')
#     (12): Concat()
#     (13): C3k2(
#       (cv1): Conv(
#         (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (14): Upsample(scale_factor=2.0, mode='nearest')
#     (15): Concat()
#     (16): C3k2(
#       (cv1): Conv(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (17): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (18): Concat()
#     (19): C3k2(
#       (cv1): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (20): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (21): Concat()
#     (22): C3k2(
#       (cv1): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): C3k(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     (23): Detect(
#       (cv2): ModuleList(
#         (0): Sequential(
#           (0): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Sequential(
#           (0): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Sequential(
#           (0): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (cv3): ModuleList(
#         (0): Sequential(
#           (0): Sequential(
#             (0): DWConv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#           (1): Sequential(
#             (0): DWConv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#           (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Sequential(
#           (0): Sequential(
#             (0): DWConv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(128, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#           (1): Sequential(
#             (0): DWConv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#           (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Sequential(
#           (0): Sequential(
#             (0): DWConv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(256, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#           (1): Sequential(
#             (0): DWConv(
#               (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(80, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#           (2): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (dfl): DFL(
#         (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#   )
# )
# Model task: detect
# layer                                    name                type  gradient  parameters               shape        mu     sigma
#     0                     model.0.conv.weight              Conv2d     False         432       [16, 3, 3, 3]  -0.00165      0.14        float32
#     1                       model.0.bn.weight         BatchNorm2d     False          16                [16]      3.07       1.9        float32
#     1                         model.0.bn.bias         BatchNorm2d     False          16                [16]     0.805      4.26        float32
#     2                             model.0.act                SiLU     False           0                  []         -         -              -
#     3                     model.1.conv.weight              Conv2d     False        4608      [32, 16, 3, 3]  0.000659    0.0564        float32
#     4                       model.1.bn.weight         BatchNorm2d     False          32                [32]      3.77     0.892        float32
#     4                         model.1.bn.bias         BatchNorm2d     False          32                [32]      1.38      1.52        float32
#     5                 model.2.cv1.conv.weight              Conv2d     False        1024      [32, 32, 1, 1]  -0.00347    0.0821        float32
#     6                   model.2.cv1.bn.weight         BatchNorm2d     False          32                [32]      2.95      1.02        float32
#     6                     model.2.cv1.bn.bias         BatchNorm2d     False          32                [32]     0.888      1.48        float32
#     7                 model.2.cv2.conv.weight              Conv2d     False        3072      [64, 48, 1, 1]  -0.00604     0.061        float32
#     8                   model.2.cv2.bn.weight         BatchNorm2d     False          64                [64]      1.93       0.8        float32
#     8                     model.2.cv2.bn.bias         BatchNorm2d     False          64                [64]   -0.0274      1.18        float32
#     9             model.2.m.0.cv1.conv.weight              Conv2d     False        1152       [8, 16, 3, 3]   -0.0041    0.0431        float32
#    10               model.2.m.0.cv1.bn.weight         BatchNorm2d     False           8                 [8]     0.647     0.516        float32
#    10                 model.2.m.0.cv1.bn.bias         BatchNorm2d     False           8                 [8]     0.318     0.993        float32
#    11             model.2.m.0.cv2.conv.weight              Conv2d     False        1152       [16, 8, 3, 3]   0.00143    0.0598        float32
#    12               model.2.m.0.cv2.bn.weight         BatchNorm2d     False          16                [16]      3.15     0.455        float32
#    12                 model.2.m.0.cv2.bn.bias         BatchNorm2d     False          16                [16]     0.971      2.88        float32
#    13                     model.3.conv.weight              Conv2d     False       36864      [64, 64, 3, 3]  -0.00137    0.0247        float32
#    14                       model.3.bn.weight         BatchNorm2d     False          64                [64]     0.967     0.257        float32
#    14                         model.3.bn.bias         BatchNorm2d     False          64                [64]     0.377      1.02        float32
#    15                 model.4.cv1.conv.weight              Conv2d     False        4096      [64, 64, 1, 1]  -0.00366    0.0509        float32
#    16                   model.4.cv1.bn.weight         BatchNorm2d     False          64                [64]     0.696     0.281        float32
#    16                     model.4.cv1.bn.bias         BatchNorm2d     False          64                [64]     0.435     0.694        float32
#    17                 model.4.cv2.conv.weight              Conv2d     False       12288     [128, 96, 1, 1]  -0.00353    0.0384        float32
#    18                   model.4.cv2.bn.weight         BatchNorm2d     False         128               [128]     0.759     0.206        float32
#    18                     model.4.cv2.bn.bias         BatchNorm2d     False         128               [128]    -0.834     0.664        float32
#    19             model.4.m.0.cv1.conv.weight              Conv2d     False        4608      [16, 32, 3, 3]   -0.0017    0.0368        float32
#    20               model.4.m.0.cv1.bn.weight         BatchNorm2d     False          16                [16]     0.531     0.165        float32
#    20                 model.4.m.0.cv1.bn.bias         BatchNorm2d     False          16                [16]     0.494     0.698        float32
#    21             model.4.m.0.cv2.conv.weight              Conv2d     False        4608      [32, 16, 3, 3]  0.000478    0.0378        float32
#    22               model.4.m.0.cv2.bn.weight         BatchNorm2d     False          32                [32]     0.781     0.173        float32
#    22                 model.4.m.0.cv2.bn.bias         BatchNorm2d     False          32                [32]      1.13         1        float32
#    23                     model.5.conv.weight              Conv2d     False      147456    [128, 128, 3, 3] -0.000495    0.0149        float32
#    24                       model.5.bn.weight         BatchNorm2d     False         128               [128]     0.712     0.215        float32
#    24                         model.5.bn.bias         BatchNorm2d     False         128               [128]     -0.16     0.791        float32
#    25                 model.6.cv1.conv.weight              Conv2d     False       16384    [128, 128, 1, 1]  -0.00264    0.0306        float32
#    26                   model.6.cv1.bn.weight         BatchNorm2d     False         128               [128]     0.855     0.289        float32
#    26                     model.6.cv1.bn.bias         BatchNorm2d     False         128               [128]    -0.147     0.703        float32
#    27                 model.6.cv2.conv.weight              Conv2d     False       24576    [128, 192, 1, 1]  -0.00231     0.028        float32
#    28                   model.6.cv2.bn.weight         BatchNorm2d     False         128               [128]     0.851     0.211        float32
#    28                     model.6.cv2.bn.bias         BatchNorm2d     False         128               [128]    -0.507     0.751        float32
#    29             model.6.m.0.cv1.conv.weight              Conv2d     False        2048      [32, 64, 1, 1]  -0.00407    0.0351        float32
#    30               model.6.m.0.cv1.bn.weight         BatchNorm2d     False          32                [32]     0.528     0.156        float32
#    30                 model.6.m.0.cv1.bn.bias         BatchNorm2d     False          32                [32]     0.344     0.558        float32
#    31             model.6.m.0.cv2.conv.weight              Conv2d     False        2048      [32, 64, 1, 1]  -0.00208    0.0222        float32
#    32               model.6.m.0.cv2.bn.weight         BatchNorm2d     False          32                [32]       1.3     0.284        float32
#    32                 model.6.m.0.cv2.bn.bias         BatchNorm2d     False          32                [32]    -0.334      0.34        float32
#    33             model.6.m.0.cv3.conv.weight              Conv2d     False        4096      [64, 64, 1, 1]  -0.00252    0.0321        float32
#    34               model.6.m.0.cv3.bn.weight         BatchNorm2d     False          64                [64]      1.04     0.227        float32
#    34                 model.6.m.0.cv3.bn.bias         BatchNorm2d     False          64                [64]    -0.382     0.613        float32
#    35         model.6.m.0.m.0.cv1.conv.weight              Conv2d     False        9216      [32, 32, 3, 3]  -0.00165     0.023        float32
#    36           model.6.m.0.m.0.cv1.bn.weight         BatchNorm2d     False          32                [32]     0.907     0.135        float32
#    36             model.6.m.0.m.0.cv1.bn.bias         BatchNorm2d     False          32                [32]    -0.611     0.498        float32
#    37         model.6.m.0.m.0.cv2.conv.weight              Conv2d     False        9216      [32, 32, 3, 3]  -0.00105     0.022        float32
#    38           model.6.m.0.m.0.cv2.bn.weight         BatchNorm2d     False          32                [32]     0.812     0.187        float32
#    38             model.6.m.0.m.0.cv2.bn.bias         BatchNorm2d     False          32                [32]      0.24     0.676        float32
#    39         model.6.m.0.m.1.cv1.conv.weight              Conv2d     False        9216      [32, 32, 3, 3]  -0.00197    0.0227        float32
#    40           model.6.m.0.m.1.cv1.bn.weight         BatchNorm2d     False          32                [32]     0.798      0.14        float32
#    40             model.6.m.0.m.1.cv1.bn.bias         BatchNorm2d     False          32                [32]    -0.578     0.565        float32
#    41         model.6.m.0.m.1.cv2.conv.weight              Conv2d     False        9216      [32, 32, 3, 3] -0.000268     0.022        float32
#    42           model.6.m.0.m.1.cv2.bn.weight         BatchNorm2d     False          32                [32]      1.06     0.215        float32
#    42             model.6.m.0.m.1.cv2.bn.bias         BatchNorm2d     False          32                [32]      1.17     0.767        float32
#    43                     model.7.conv.weight              Conv2d     False      294912    [256, 128, 3, 3] -0.000359    0.0108        float32
#    44                       model.7.bn.weight         BatchNorm2d     False         256               [256]     0.879     0.222        float32
#    44                         model.7.bn.bias         BatchNorm2d     False         256               [256]    -0.541     0.597        float32
#    45                 model.8.cv1.conv.weight              Conv2d     False       65536    [256, 256, 1, 1]  -0.00186    0.0186        float32
#    46                   model.8.cv1.bn.weight         BatchNorm2d     False         256               [256]      1.11     0.177        float32
#    46                     model.8.cv1.bn.bias         BatchNorm2d     False         256               [256]    -0.682     0.573        float32
#    47                 model.8.cv2.conv.weight              Conv2d     False       98304    [256, 384, 1, 1]  -0.00161    0.0168        float32
#    48                   model.8.cv2.bn.weight         BatchNorm2d     False         256               [256]       1.2      0.26        float32
#    48                     model.8.cv2.bn.bias         BatchNorm2d     False         256               [256]    -0.479     0.633        float32
#    49             model.8.m.0.cv1.conv.weight              Conv2d     False        8192     [64, 128, 1, 1]  -0.00251    0.0231        float32
#    50               model.8.m.0.cv1.bn.weight         BatchNorm2d     False          64                [64]     0.666     0.233        float32
#    50                 model.8.m.0.cv1.bn.bias         BatchNorm2d     False          64                [64]    -0.106     0.576        float32
#    51             model.8.m.0.cv2.conv.weight              Conv2d     False        8192     [64, 128, 1, 1]   -0.0014    0.0145        float32
#    52               model.8.m.0.cv2.bn.weight         BatchNorm2d     False          64                [64]      1.41     0.125        float32
#    52                 model.8.m.0.cv2.bn.bias         BatchNorm2d     False          64                [64]    -0.264     0.154        float32
#    53             model.8.m.0.cv3.conv.weight              Conv2d     False       16384    [128, 128, 1, 1]   -0.0016    0.0206        float32
#    54               model.8.m.0.cv3.bn.weight         BatchNorm2d     False         128               [128]      1.28     0.206        float32
#    54                 model.8.m.0.cv3.bn.bias         BatchNorm2d     False         128               [128]    -0.696     0.474        float32
#    55         model.8.m.0.m.0.cv1.conv.weight              Conv2d     False       36864      [64, 64, 3, 3]  -0.00131     0.014        float32
#    56           model.8.m.0.m.0.cv1.bn.weight         BatchNorm2d     False          64                [64]      1.35     0.184        float32
#    56             model.8.m.0.m.0.cv1.bn.bias         BatchNorm2d     False          64                [64]    -0.922     0.582        float32
#    57         model.8.m.0.m.0.cv2.conv.weight              Conv2d     False       36864      [64, 64, 3, 3] -0.000846    0.0135        float32
#    58           model.8.m.0.m.0.cv2.bn.weight         BatchNorm2d     False          64                [64]      1.15      0.34        float32
#    58             model.8.m.0.m.0.cv2.bn.bias         BatchNorm2d     False          64                [64]   -0.0465     0.716        float32
#    59         model.8.m.0.m.1.cv1.conv.weight              Conv2d     False       36864      [64, 64, 3, 3]  -0.00116    0.0134        float32
#    60           model.8.m.0.m.1.cv1.bn.weight         BatchNorm2d     False          64                [64]      1.29     0.221        float32
#    60             model.8.m.0.m.1.cv1.bn.bias         BatchNorm2d     False          64                [64]    -0.553     0.675        float32
#    61         model.8.m.0.m.1.cv2.conv.weight              Conv2d     False       36864      [64, 64, 3, 3] -0.000543    0.0132        float32
#    62           model.8.m.0.m.1.cv2.bn.weight         BatchNorm2d     False          64                [64]      1.64     0.462        float32
#    62             model.8.m.0.m.1.cv2.bn.bias         BatchNorm2d     False          64                [64]     0.456     0.757        float32
#    63                 model.9.cv1.conv.weight              Conv2d     False       32768    [128, 256, 1, 1]  -0.00327    0.0232        float32
#    64                   model.9.cv1.bn.weight         BatchNorm2d     False         128               [128]     0.804     0.102        float32
#    64                     model.9.cv1.bn.bias         BatchNorm2d     False         128               [128]      1.99      0.43        float32
#    65                 model.9.cv2.conv.weight              Conv2d     False      131072    [256, 512, 1, 1]  0.000171    0.0151        float32
#    66                   model.9.cv2.bn.weight         BatchNorm2d     False         256               [256]     0.899     0.272        float32
#    66                     model.9.cv2.bn.bias         BatchNorm2d     False         256               [256]     -1.18      1.03        float32
#    67                               model.9.m           MaxPool2d     False           0                  []         -         -              -
#    68                model.10.cv1.conv.weight              Conv2d     False       65536    [256, 256, 1, 1]  -0.00251    0.0197        float32
#    69                  model.10.cv1.bn.weight         BatchNorm2d     False         256               [256]      1.47      0.33        float32
#    69                    model.10.cv1.bn.bias         BatchNorm2d     False         256               [256]    -0.205     0.649        float32
#    70                model.10.cv2.conv.weight              Conv2d     False       65536    [256, 256, 1, 1]  -0.00118    0.0184        float32
#    71                  model.10.cv2.bn.weight         BatchNorm2d     False         256               [256]     0.994     0.232        float32
#    71                    model.10.cv2.bn.bias         BatchNorm2d     False         256               [256]     -1.02     0.699        float32
#    72       model.10.m.0.attn.qkv.conv.weight              Conv2d     False       32768    [256, 128, 1, 1]  0.000541    0.0224        float32
#    73         model.10.m.0.attn.qkv.bn.weight         BatchNorm2d     False         256               [256]      1.18     0.409        float32
#    73           model.10.m.0.attn.qkv.bn.bias         BatchNorm2d     False         256               [256]   -0.0338     0.345        float32
#    74               model.10.m.0.attn.qkv.act            Identity     False           0                  []         -         -              -
#    75      model.10.m.0.attn.proj.conv.weight              Conv2d     False       16384    [128, 128, 1, 1]  0.000203    0.0221        float32
#    76        model.10.m.0.attn.proj.bn.weight         BatchNorm2d     False         128               [128]     0.751     0.153        float32
#    76          model.10.m.0.attn.proj.bn.bias         BatchNorm2d     False         128               [128] -7.34e-06   8.7e-05        float32
#    77              model.10.m.0.attn.proj.act            Identity     False           0                  []         -         -              -
#    78        model.10.m.0.attn.pe.conv.weight              Conv2d     False        1152      [128, 1, 3, 3]   -0.0134    0.0415        float32
#    79          model.10.m.0.attn.pe.bn.weight         BatchNorm2d     False         128               [128]     0.824     0.327        float32
#    79            model.10.m.0.attn.pe.bn.bias         BatchNorm2d     False         128               [128] -1.11e-05  9.13e-05        float32
#    80                model.10.m.0.attn.pe.act            Identity     False           0                  []         -         -              -
#    81          model.10.m.0.ffn.0.conv.weight              Conv2d     False       32768    [256, 128, 1, 1]  -0.00129    0.0177        float32
#    82            model.10.m.0.ffn.0.bn.weight         BatchNorm2d     False         256               [256]     0.974     0.115        float32
#    82              model.10.m.0.ffn.0.bn.bias         BatchNorm2d     False         256               [256]      -1.5     0.204        float32
#    83          model.10.m.0.ffn.1.conv.weight              Conv2d     False       32768    [128, 256, 1, 1]  0.000214    0.0154        float32
#    84            model.10.m.0.ffn.1.bn.weight         BatchNorm2d     False         128               [128]     0.687     0.125        float32
#    84              model.10.m.0.ffn.1.bn.bias         BatchNorm2d     False         128               [128]    -4e-06  5.84e-05        float32
#    85                  model.10.m.0.ffn.1.act            Identity     False           0                  []         -         -              -
#    86                                model.11            Upsample     False           0                  []         -         -              -
#    87                                model.12              Concat     False           0                  []         -         -              -
#    88                model.13.cv1.conv.weight              Conv2d     False       49152    [128, 384, 1, 1]  -0.00111    0.0211        float32
#    89                  model.13.cv1.bn.weight         BatchNorm2d     False         128               [128]     0.716     0.204        float32
#    89                    model.13.cv1.bn.bias         BatchNorm2d     False         128               [128]    -0.281      0.84        float32
#    90                model.13.cv2.conv.weight              Conv2d     False       24576    [128, 192, 1, 1]  -0.00186    0.0238        float32
#    91                  model.13.cv2.bn.weight         BatchNorm2d     False         128               [128]     0.627     0.202        float32
#    91                    model.13.cv2.bn.bias         BatchNorm2d     False         128               [128]    -0.391     0.631        float32
#    92            model.13.m.0.cv1.conv.weight              Conv2d     False       18432      [32, 64, 3, 3]  -0.00123    0.0208        float32
#    93              model.13.m.0.cv1.bn.weight         BatchNorm2d     False          32                [32]     0.692     0.133        float32
#    93                model.13.m.0.cv1.bn.bias         BatchNorm2d     False          32                [32]    -0.328     0.693        float32
#    94            model.13.m.0.cv2.conv.weight              Conv2d     False       18432      [64, 32, 3, 3]  -0.00121    0.0198        float32
#    95              model.13.m.0.cv2.bn.weight         BatchNorm2d     False          64                [64]     0.883     0.202        float32
#    95                model.13.m.0.cv2.bn.bias         BatchNorm2d     False          64                [64]     0.104      0.71        float32
#    96                                model.14            Upsample     False           0                  []         -         -              -
#    97                                model.15              Concat     False           0                  []         -         -              -
#    98                model.16.cv1.conv.weight              Conv2d     False       16384     [64, 256, 1, 1]  -0.00171    0.0242        float32
#    99                  model.16.cv1.bn.weight         BatchNorm2d     False          64                [64]      0.45     0.186        float32
#    99                    model.16.cv1.bn.bias         BatchNorm2d     False          64                [64]    0.0858     0.879        float32
#   100                model.16.cv2.conv.weight              Conv2d     False        6144      [64, 96, 1, 1]  0.000416    0.0329        float32
#   101                  model.16.cv2.bn.weight         BatchNorm2d     False          64                [64]     0.543      0.26        float32
#   101                    model.16.cv2.bn.bias         BatchNorm2d     False          64                [64]     0.125     0.839        float32
#   102            model.16.m.0.cv1.conv.weight              Conv2d     False        4608      [16, 32, 3, 3]  -0.00168     0.029        float32
#   103              model.16.m.0.cv1.bn.weight         BatchNorm2d     False          16                [16]     0.661     0.142        float32
#   103                model.16.m.0.cv1.bn.bias         BatchNorm2d     False          16                [16]    0.0959     0.687        float32
#   104            model.16.m.0.cv2.conv.weight              Conv2d     False        4608      [32, 16, 3, 3] -0.000963    0.0312        float32
#   105              model.16.m.0.cv2.bn.weight         BatchNorm2d     False          32                [32]     0.768     0.213        float32
#   105                model.16.m.0.cv2.bn.bias         BatchNorm2d     False          32                [32]    0.0741     0.762        float32
#   106                    model.17.conv.weight              Conv2d     False       36864      [64, 64, 3, 3] -0.000343    0.0124        float32
#   107                      model.17.bn.weight         BatchNorm2d     False          64                [64]     0.771     0.176        float32
#   107                        model.17.bn.bias         BatchNorm2d     False          64                [64]    -0.622     0.593        float32
#   108                                model.18              Concat     False           0                  []         -         -              -
#   109                model.19.cv1.conv.weight              Conv2d     False       24576    [128, 192, 1, 1]  -0.00103    0.0189        float32
#   110                  model.19.cv1.bn.weight         BatchNorm2d     False         128               [128]     0.672     0.196        float32
#   110                    model.19.cv1.bn.bias         BatchNorm2d     False         128               [128]    -0.267     0.603        float32
#   111                model.19.cv2.conv.weight              Conv2d     False       24576    [128, 192, 1, 1]  -0.00052    0.0186        float32
#   112                  model.19.cv2.bn.weight         BatchNorm2d     False         128               [128]     0.769     0.282        float32
#   112                    model.19.cv2.bn.bias         BatchNorm2d     False         128               [128]    -0.423     0.652        float32
#   113            model.19.m.0.cv1.conv.weight              Conv2d     False       18432      [32, 64, 3, 3]  -0.00123    0.0177        float32
#   114              model.19.m.0.cv1.bn.weight         BatchNorm2d     False          32                [32]     0.907     0.228        float32
#   114                model.19.m.0.cv1.bn.bias         BatchNorm2d     False          32                [32]    -0.252      0.78        float32
#   115            model.19.m.0.cv2.conv.weight              Conv2d     False       18432      [64, 32, 3, 3]  -0.00091    0.0175        float32
#   116              model.19.m.0.cv2.bn.weight         BatchNorm2d     False          64                [64]      1.19     0.249        float32
#   116                model.19.m.0.cv2.bn.bias         BatchNorm2d     False          64                [64]    -0.168     0.578        float32
#   117                    model.20.conv.weight              Conv2d     False      147456    [128, 128, 3, 3] -0.000307   0.00708        float32
#   118                      model.20.bn.weight         BatchNorm2d     False         128               [128]     0.939     0.195        float32
#   118                        model.20.bn.bias         BatchNorm2d     False         128               [128]    -0.584     0.345        float32
#   119                                model.21              Concat     False           0                  []         -         -              -
#   120                model.22.cv1.conv.weight              Conv2d     False       98304    [256, 384, 1, 1] -0.000877    0.0117        float32
#   121                  model.22.cv1.bn.weight         BatchNorm2d     False         256               [256]       1.1     0.181        float32
#   121                    model.22.cv1.bn.bias         BatchNorm2d     False         256               [256]    -0.656     0.443        float32
#   122                model.22.cv2.conv.weight              Conv2d     False       98304    [256, 384, 1, 1] -0.000582   0.00943        float32
#   123                  model.22.cv2.bn.weight         BatchNorm2d     False         256               [256]      1.06      0.38        float32
#   123                    model.22.cv2.bn.bias         BatchNorm2d     False         256               [256]    -0.563     0.425        float32
#   124            model.22.m.0.cv1.conv.weight              Conv2d     False        8192     [64, 128, 1, 1]  -0.00211      0.02        float32
#   125              model.22.m.0.cv1.bn.weight         BatchNorm2d     False          64                [64]     0.358     0.148        float32
#   125                model.22.m.0.cv1.bn.bias         BatchNorm2d     False          64                [64]    -0.186      0.44        float32
#   126            model.22.m.0.cv2.conv.weight              Conv2d     False        8192     [64, 128, 1, 1] -0.000656   0.00748        float32
#   127              model.22.m.0.cv2.bn.weight         BatchNorm2d     False          64                [64]      1.15     0.111        float32
#   127                model.22.m.0.cv2.bn.bias         BatchNorm2d     False          64                [64]    -0.125     0.111        float32
#   128            model.22.m.0.cv3.conv.weight              Conv2d     False       16384    [128, 128, 1, 1] -0.000809    0.0139        float32
#   129              model.22.m.0.cv3.bn.weight         BatchNorm2d     False         128               [128]      1.33     0.368        float32
#   129                model.22.m.0.cv3.bn.bias         BatchNorm2d     False         128               [128]    -0.425     0.557        float32
#   130        model.22.m.0.m.0.cv1.conv.weight              Conv2d     False       36864      [64, 64, 3, 3] -0.000836    0.0125        float32
#   131          model.22.m.0.m.0.cv1.bn.weight         BatchNorm2d     False          64                [64]      1.05     0.207        float32
#   131            model.22.m.0.m.0.cv1.bn.bias         BatchNorm2d     False          64                [64]    -0.781     0.649        float32
#   132        model.22.m.0.m.0.cv2.conv.weight              Conv2d     False       36864      [64, 64, 3, 3] -0.000624     0.012        float32
#   133          model.22.m.0.m.0.cv2.bn.weight         BatchNorm2d     False          64                [64]      0.94      0.24        float32
#   133            model.22.m.0.m.0.cv2.bn.bias         BatchNorm2d     False          64                [64]     -0.25     0.694        float32
#   134        model.22.m.0.m.1.cv1.conv.weight              Conv2d     False       36864      [64, 64, 3, 3] -0.000981    0.0117        float32
#   135          model.22.m.0.m.1.cv1.bn.weight         BatchNorm2d     False          64                [64]     0.926     0.233        float32
#   135            model.22.m.0.m.1.cv1.bn.bias         BatchNorm2d     False          64                [64]    -0.813     0.648        float32
#   136        model.22.m.0.m.1.cv2.conv.weight              Conv2d     False       36864      [64, 64, 3, 3] -2.36e-06    0.0108        float32
#   137          model.22.m.0.m.1.cv2.bn.weight         BatchNorm2d     False          64                [64]       1.7     0.405        float32
#   137            model.22.m.0.m.1.cv2.bn.bias         BatchNorm2d     False          64                [64]     0.175     0.628        float32
#   138            model.23.cv2.0.0.conv.weight              Conv2d     False       36864      [64, 64, 3, 3] -0.000899    0.0128        float32
#   139              model.23.cv2.0.0.bn.weight         BatchNorm2d     False          64                [64]     0.781     0.269        float32
#   139                model.23.cv2.0.0.bn.bias         BatchNorm2d     False          64                [64]    -0.617     0.595        float32
#   140            model.23.cv2.0.1.conv.weight              Conv2d     False       36864      [64, 64, 3, 3] -0.000355    0.0111        float32
#   141              model.23.cv2.0.1.bn.weight         BatchNorm2d     False          64                [64]      2.51       1.1        float32
#   141                model.23.cv2.0.1.bn.bias         BatchNorm2d     False          64                [64]     0.856     0.831        float32
#   142                 model.23.cv2.0.2.weight              Conv2d     False        4096      [64, 64, 1, 1]  1.74e-07    0.0478        float32
#   142                   model.23.cv2.0.2.bias              Conv2d     False          64                [64]     0.998     0.936        float32
#   143            model.23.cv2.1.0.conv.weight              Conv2d     False       73728     [64, 128, 3, 3] -0.000417   0.00831        float32
#   144              model.23.cv2.1.0.bn.weight         BatchNorm2d     False          64                [64]      1.25     0.478        float32
#   144                model.23.cv2.1.0.bn.bias         BatchNorm2d     False          64                [64]    -0.448     0.632        float32
#   145            model.23.cv2.1.1.conv.weight              Conv2d     False       36864      [64, 64, 3, 3]  -0.00022      0.01        float32
#   146              model.23.cv2.1.1.bn.weight         BatchNorm2d     False          64                [64]      2.67       1.1        float32
#   146                model.23.cv2.1.1.bn.bias         BatchNorm2d     False          64                [64]     0.707     0.634        float32
#   147                 model.23.cv2.1.2.weight              Conv2d     False        4096      [64, 64, 1, 1]  1.17e-06    0.0506        float32
#   147                   model.23.cv2.1.2.bias              Conv2d     False          64                [64]     0.998      1.05        float32
#   148            model.23.cv2.2.0.conv.weight              Conv2d     False      147456     [64, 256, 3, 3] -0.000194   0.00543        float32
#   149              model.23.cv2.2.0.bn.weight         BatchNorm2d     False          64                [64]      1.44     0.342        float32
#   149                model.23.cv2.2.0.bn.bias         BatchNorm2d     False          64                [64]    -0.353      0.62        float32
#   150            model.23.cv2.2.1.conv.weight              Conv2d     False       36864      [64, 64, 3, 3] -0.000113   0.00956        float32
#   151              model.23.cv2.2.1.bn.weight         BatchNorm2d     False          64                [64]      3.07     0.958        float32
#   151                model.23.cv2.2.1.bn.bias         BatchNorm2d     False          64                [64]     0.785     0.629        float32
#   152                 model.23.cv2.2.2.weight              Conv2d     False        4096      [64, 64, 1, 1]  3.79e-06    0.0563        float32
#   152                   model.23.cv2.2.2.bias              Conv2d     False          64                [64]     0.998      1.02        float32
#   153          model.23.cv3.0.0.0.conv.weight              Conv2d     False         576       [64, 1, 3, 3]   0.00324    0.0279        float32
#   154            model.23.cv3.0.0.0.bn.weight         BatchNorm2d     False          64                [64]     0.552      0.33        float32
#   154              model.23.cv3.0.0.0.bn.bias         BatchNorm2d     False          64                [64]      1.13       1.1        float32
#   155          model.23.cv3.0.0.1.conv.weight              Conv2d     False        5120      [80, 64, 1, 1]   0.00167    0.0228        float32
#   156            model.23.cv3.0.0.1.bn.weight         BatchNorm2d     False          80                [80]     0.647     0.226        float32
#   156              model.23.cv3.0.0.1.bn.bias         BatchNorm2d     False          80                [80]    -0.188     0.805        float32
#   157          model.23.cv3.0.1.0.conv.weight              Conv2d     False         720       [80, 1, 3, 3]   0.00502    0.0317        float32
#   158            model.23.cv3.0.1.0.bn.weight         BatchNorm2d     False          80                [80]     0.634     0.294        float32
#   158              model.23.cv3.0.1.0.bn.bias         BatchNorm2d     False          80                [80]     0.976     0.678        float32
#   159          model.23.cv3.0.1.1.conv.weight              Conv2d     False        6400      [80, 80, 1, 1]  -0.00167    0.0238        float32
#   160            model.23.cv3.0.1.1.bn.weight         BatchNorm2d     False          80                [80]      2.74     0.478        float32
#   160              model.23.cv3.0.1.1.bn.bias         BatchNorm2d     False          80                [80]      1.22      1.94        float32
#   161                 model.23.cv3.0.2.weight              Conv2d     False        6400      [80, 80, 1, 1]  -0.00875    0.0481        float32
#   161                   model.23.cv3.0.2.bias              Conv2d     False          80                [80]     -11.6     0.942        float32
#   162          model.23.cv3.1.0.0.conv.weight              Conv2d     False        1152      [128, 1, 3, 3]   0.00635    0.0214        float32
#   163            model.23.cv3.1.0.0.bn.weight         BatchNorm2d     False         128               [128]     0.798     0.253        float32
#   163              model.23.cv3.1.0.0.bn.bias         BatchNorm2d     False         128               [128]      0.54     0.764        float32
#   164          model.23.cv3.1.0.1.conv.weight              Conv2d     False       10240     [80, 128, 1, 1]  1.31e-05    0.0172        float32
#   165            model.23.cv3.1.0.1.bn.weight         BatchNorm2d     False          80                [80]      0.83     0.343        float32
#   165              model.23.cv3.1.0.1.bn.bias         BatchNorm2d     False          80                [80]   -0.0698     0.729        float32
#   166          model.23.cv3.1.1.0.conv.weight              Conv2d     False         720       [80, 1, 3, 3]   0.00383     0.028        float32
#   167            model.23.cv3.1.1.0.bn.weight         BatchNorm2d     False          80                [80]      0.74     0.378        float32
#   167              model.23.cv3.1.1.0.bn.bias         BatchNorm2d     False          80                [80]     0.731     0.748        float32
#   168          model.23.cv3.1.1.1.conv.weight              Conv2d     False        6400      [80, 80, 1, 1] -0.000902    0.0225        float32
#   169            model.23.cv3.1.1.1.bn.weight         BatchNorm2d     False          80                [80]       2.9      0.75        float32
#   169              model.23.cv3.1.1.1.bn.bias         BatchNorm2d     False          80                [80]      1.27      1.68        float32
#   170                 model.23.cv3.1.2.weight              Conv2d     False        6400      [80, 80, 1, 1]   -0.0103    0.0488        float32
#   170                   model.23.cv3.1.2.bias              Conv2d     False          80                [80]     -10.4     0.725        float32
#   171          model.23.cv3.2.0.0.conv.weight              Conv2d     False        2304      [256, 1, 3, 3]   0.00395    0.0176        float32
#   172            model.23.cv3.2.0.0.bn.weight         BatchNorm2d     False         256               [256]      1.01     0.259        float32
#   172              model.23.cv3.2.0.0.bn.bias         BatchNorm2d     False         256               [256]      0.15     0.372        float32
#   173          model.23.cv3.2.0.1.conv.weight              Conv2d     False       20480     [80, 256, 1, 1] -0.000449    0.0123        float32
#   174            model.23.cv3.2.0.1.bn.weight         BatchNorm2d     False          80                [80]      1.08     0.303        float32
#   174              model.23.cv3.2.0.1.bn.bias         BatchNorm2d     False          80                [80]    -0.023     0.695        float32
#   175          model.23.cv3.2.1.0.conv.weight              Conv2d     False         720       [80, 1, 3, 3]    0.0051    0.0224        float32
#   176            model.23.cv3.2.1.0.bn.weight         BatchNorm2d     False          80                [80]     0.838     0.391        float32
#   176              model.23.cv3.2.1.0.bn.bias         BatchNorm2d     False          80                [80]     0.683     0.798        float32
#   177          model.23.cv3.2.1.1.conv.weight              Conv2d     False        6400      [80, 80, 1, 1]  -0.00218      0.02        float32
#   178            model.23.cv3.2.1.1.bn.weight         BatchNorm2d     False          80                [80]      3.16     0.736        float32
#   178              model.23.cv3.2.1.1.bn.bias         BatchNorm2d     False          80                [80]      1.54      1.46        float32
#   179                 model.23.cv3.2.2.weight              Conv2d     False        6400      [80, 80, 1, 1]    -0.011    0.0476        float32
#   179                   model.23.cv3.2.2.bias              Conv2d     False          80                [80]     -9.08      0.75        float32
#   180                model.23.dfl.conv.weight              Conv2d     False          16       [1, 16, 1, 1]       7.5      4.76        float32
# YOLO11n summary: 181 layers, 2,624,080 parameters, 0 gradients, 6.6 GFLOPs
#
# Model loaded successfully and ready for training!

# %%
# Copilot prompt:
# Train the YOLO model using the dataset in item-1/data.yaml for 100 epochs with image size 640, batch size 16.
# Save results and model weights automatically to the 'runs/train' directory.

if model is not None:
    try:
        # Train the YOLO model
        print("Starting YOLO training...")
        results = model.train(
            data=f"{dataset_path}/data.yaml",
            epochs=100,
            imgsz=640,
            batch=16,
            device=device,
            project='YOLO11N',
            name='train',
            save=True,
            cache=True,
            workers=4,
            patience=50,  # Early stopping patience
            save_period=10,  # Save checkpoint every 10 epochs
        )
        
        print("Training completed successfully!")
        print(f"Results saved to: {results.save_dir}")
        print(f"Best model weights: {results.save_dir}/weights/best.pt")
        print(f"Last model weights: {results.save_dir}/weights/last.pt")
        
        # Store the results for later use
        training_results = results
        
    except Exception as e:
        print(f"Training failed with error: {str(e)}")
        print("Please ensure your dataset has images and labels in the correct directories.")
        training_results = None
else:
    print("Model not loaded. Cannot start training.")
    training_results = None
# Out:
# Starting YOLO training...
# New https://pypi.org/project/ultralytics/8.3.208 available  Update with 'pip install -U ultralytics'
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=.././data/mp4/dataset/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=50, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=YOLO11N, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=34
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    437302  ultralytics.nn.modules.head.Detect           [34, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,596,470 parameters, 2,596,454 gradients, 6.5 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 103.8226.3 MB/s, size: 57.2 KB)
# train: Scanning C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\data\mp4\dataset\train\labels.cache... 16284 images, 4 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 16284/16284 28.4Mit/s 0.0s
# train: C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\data\mp4\dataset\train\images\coffee0246.jpg: 1 duplicate labels removed
# WARNING train: 22.6GB RAM required to cache images with 50% safety margin but only 10.6/23.7GB available, not caching images
# val: Fast image access  (ping: 0.00.0 ms, read: 128.157.8 MB/s, size: 61.3 KB)
# val: Scanning C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\data\mp4\dataset\test\labels.cache... 883 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 883/883 860.3Kit/s 0.0s
# WARNING cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.8GB RAM): 100% ━━━━━━━━━━━━ 883/883 2.9Kit/s 0.3s<0.0s
# Plotting labels to C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# 2025/10/10 10:49:43 INFO mlflow.tracking.fluent: Experiment with name 'YOLO11N' does not exist. Creating a new experiment.
# MLflow: logging run_id(914159f2434f459f83defd26cd1bf245) to runs\mlflow
# MLflow: view at http://127.0.0.1:5000 with 'mlflow server --backend-store-uri runs\mlflow'
# MLflow: disable with 'yolo settings mlflow=False'
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100       3.3G     0.9269      3.449      1.184         46        640: 100% ━━━━━━━━━━━━ 1018/1018 5.2it/s 3:14<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 2.0it/s 13.8s0.2s
#                    all        883       2324      0.707      0.554      0.622      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.75G     0.9542      1.853      1.181         45        640: 100% ━━━━━━━━━━━━ 1018/1018 5.8it/s 2:56<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.9it/s 4.1s0.1s
#                    all        883       2324      0.722      0.668      0.721      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.75G      1.032      1.718      1.215         64        640: 100% ━━━━━━━━━━━━ 1018/1018 6.4it/s 2:40<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.768      0.521      0.629      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.75G      1.069      1.624      1.227        106        640: 100% ━━━━━━━━━━━━ 1018/1018 6.4it/s 2:40<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.8it/s 4.1s0.1s
#                    all        883       2324      0.701      0.576      0.665      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.75G      1.017      1.353      1.193         76        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:42<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.1it/s 4.0s0.1s
#                    all        883       2324      0.847      0.794      0.868      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      3.07G     0.9643      1.143      1.156         30        640: 100% ━━━━━━━━━━━━ 1018/1018 6.5it/s 2:36<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.2it/s 3.9s0.1s
#                    all        883       2324      0.887      0.795      0.877      0.712
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.94G     0.9274      1.029      1.138         46        640: 100% ━━━━━━━━━━━━ 1018/1018 6.5it/s 2:37<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.871      0.786      0.876      0.707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.95G     0.9019     0.9421      1.118         35        640: 100% ━━━━━━━━━━━━ 1018/1018 6.4it/s 2:39<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.1it/s 4.0s0.1s
#                    all        883       2324      0.891      0.847      0.909      0.738
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.95G     0.8863     0.8809      1.107         47        640: 100% ━━━━━━━━━━━━ 1018/1018 6.4it/s 2:39<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.899      0.877      0.932      0.762
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.95G     0.8624     0.8373      1.096         49        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:43<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.901      0.891      0.935      0.774
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.95G     0.8507     0.8093      1.087         60        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:41<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.1it/s 3.9s0.1s
#                    all        883       2324      0.908      0.904      0.944      0.787
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.95G     0.8298     0.7652      1.077         77        640: 100% ━━━━━━━━━━━━ 1018/1018 6.4it/s 2:39<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.1it/s 4.0s0.1s
#                    all        883       2324      0.919      0.888      0.944      0.788
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      3.75G     0.8302     0.7557      1.076         61        640: 100% ━━━━━━━━━━━━ 1018/1018 6.4it/s 2:39<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.916      0.907      0.947        0.8
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100       3.1G     0.8248     0.7384      1.072         70        640: 100% ━━━━━━━━━━━━ 1018/1018 6.4it/s 2:39<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.1it/s 3.9s0.1s
#                    all        883       2324      0.936      0.908      0.953      0.809
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.99G      0.808     0.7074      1.064         81        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:42<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.1it/s 4.0s0.1s
#                    all        883       2324      0.929      0.917      0.953       0.81
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      3.37G     0.8019     0.7045      1.063         38        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:43<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.1it/s 3.9s0.1s
#                    all        883       2324      0.928      0.921      0.959      0.818
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.86G     0.7924     0.6858      1.059        161        640: 100% ━━━━━━━━━━━━ 1018/1018 6.4it/s 2:40<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.925      0.921      0.955      0.814
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      3.39G     0.7932     0.6792      1.058         51        640: 100% ━━━━━━━━━━━━ 1018/1018 6.1it/s 2:46<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.7it/s 4.2s0.1s
#                    all        883       2324       0.93      0.918      0.957      0.824
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.97G     0.7832     0.6563       1.05         47        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 5.7it/s 4.9s0.2s
#                    all        883       2324      0.933      0.931      0.963      0.827
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      2.97G     0.7732      0.643      1.047         86        640: 100% ━━━━━━━━━━━━ 1018/1018 5.8it/s 2:55<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 5.9it/s 4.8s0.2s
#                    all        883       2324      0.931      0.938      0.963      0.839
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      2.97G     0.7739      0.639      1.047         53        640: 100% ━━━━━━━━━━━━ 1018/1018 5.9it/s 2:53<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.2it/s 4.5s0.2s
#                    all        883       2324      0.948      0.926      0.965      0.835
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.97G     0.7658     0.6264      1.042         58        640: 100% ━━━━━━━━━━━━ 1018/1018 5.9it/s 2:53<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.1it/s 4.6s0.2s
#                    all        883       2324      0.941      0.933      0.965      0.839
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2.97G     0.7615     0.6158       1.04         65        640: 100% ━━━━━━━━━━━━ 1018/1018 6.0it/s 2:50<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.2it/s 3.9s0.1s
#                    all        883       2324      0.937      0.933      0.964      0.841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      2.97G     0.7486     0.6004      1.037         87        640: 100% ━━━━━━━━━━━━ 1018/1018 5.8it/s 2:55<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.0it/s 4.7s0.1s
#                    all        883       2324      0.942      0.936      0.968      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      2.97G     0.7525     0.5974      1.036         81        640: 100% ━━━━━━━━━━━━ 1018/1018 5.8it/s 2:56<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.0it/s 4.7s0.2s
#                    all        883       2324      0.946      0.945      0.969      0.848
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      2.97G      0.741     0.5927      1.032         43        640: 100% ━━━━━━━━━━━━ 1018/1018 6.1it/s 2:46<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.2it/s 3.9s0.1s
#                    all        883       2324      0.939      0.943      0.968      0.847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      2.97G     0.7425      0.589       1.03         82        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:42<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.1it/s 4.0s0.1s
#                    all        883       2324      0.955      0.941       0.97      0.849
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      2.97G      0.738     0.5807      1.021         45        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:42<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.1it/s 4.0s0.1s
#                    all        883       2324      0.948      0.935      0.967      0.848
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      2.97G      0.736     0.5698      1.019         30        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:42<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.1it/s 4.0s0.1s
#                    all        883       2324       0.94       0.94      0.968      0.852
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      2.97G      0.731      0.567      1.017         59        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:43<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.1it/s 3.9s0.1s
#                    all        883       2324      0.946      0.944       0.97      0.852
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      2.98G     0.7279     0.5625      1.016         51        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:44<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.9it/s 4.0s0.1s
#                    all        883       2324      0.945      0.944      0.969      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      2.98G     0.7255     0.5563      1.013         48        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:44<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.951      0.947      0.973      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      2.98G     0.7212     0.5459       1.01         49        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:44<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.8it/s 4.1s0.1s
#                    all        883       2324      0.955      0.946      0.973      0.859
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      2.98G     0.7167      0.544      1.008         41        640: 100% ━━━━━━━━━━━━ 1018/1018 5.9it/s 2:53<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 5.3it/s 5.3s0.2s
#                    all        883       2324      0.956      0.938      0.971       0.86
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      2.98G     0.7136     0.5366      1.007         61        640: 100% ━━━━━━━━━━━━ 1018/1018 5.6it/s 3:01<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 5.7it/s 4.9s0.2s
#                    all        883       2324      0.954      0.947      0.973       0.86
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      2.98G     0.7132     0.5354      1.008         88        640: 100% ━━━━━━━━━━━━ 1018/1018 5.7it/s 2:59<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 5.8it/s 4.8s0.2s
#                    all        883       2324      0.945      0.954      0.975      0.862
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      2.98G     0.7096     0.5339      1.003         53        640: 100% ━━━━━━━━━━━━ 1018/1018 5.7it/s 2:60<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 5.7it/s 4.9s0.2s
#                    all        883       2324      0.951       0.95      0.974      0.864
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      2.98G     0.7091     0.5287      1.005         32        640: 100% ━━━━━━━━━━━━ 1018/1018 5.8it/s 2:56<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 5.8it/s 4.9s0.2s
#                    all        883       2324      0.941       0.95      0.973      0.861
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      2.98G     0.7006     0.5186      0.999         70        640: 100% ━━━━━━━━━━━━ 1018/1018 5.7it/s 2:57<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.946      0.942      0.973      0.864
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      2.98G     0.7018     0.5174     0.9987         33        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:42<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.2it/s 3.9s0.1s
#                    all        883       2324      0.947      0.943      0.974      0.865
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      2.98G      0.697     0.5124      1.001         51        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:43<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.958      0.935      0.974      0.865
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      2.98G     0.6971     0.5143     0.9962         52        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.953      0.949      0.975      0.866
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      2.98G     0.6938     0.5106     0.9966         64        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:42<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.955      0.943      0.975      0.868
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      2.98G     0.6856     0.4985     0.9956         45        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:42<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.1it/s 4.0s0.1s
#                    all        883       2324      0.957      0.946      0.976      0.868
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      2.98G     0.6876     0.4929     0.9905         37        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:42<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.9it/s 4.0s0.1s
#                    all        883       2324      0.955      0.948      0.976      0.866
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      2.98G     0.6879     0.4969     0.9932         52        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:43<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.9it/s 4.1s0.1s
#                    all        883       2324      0.954      0.949      0.976      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      2.98G     0.6767     0.4856     0.9895         43        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:43<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.1it/s 3.9s0.1s
#                    all        883       2324      0.952       0.95      0.975      0.871
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      2.98G     0.6841     0.4885     0.9892         60        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:43<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.1it/s 4.0s0.1s
#                    all        883       2324      0.958      0.945      0.975      0.871
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      2.98G     0.6766     0.4837     0.9879         50        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:44<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.957      0.946      0.976      0.872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      2.98G     0.6774     0.4801      0.987         48        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:44<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324       0.95      0.956      0.977      0.872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      2.98G     0.6706     0.4789      0.986         53        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:42<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.951       0.96      0.978      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      2.98G      0.674     0.4788     0.9876         87        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:44<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.9it/s 4.1s0.1s
#                    all        883       2324      0.952      0.958      0.977      0.872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      2.98G     0.6707     0.4736      0.983         48        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:44<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.1it/s 3.9s0.1s
#                    all        883       2324      0.952      0.956      0.977      0.872
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      2.98G      0.668     0.4693     0.9844         54        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:44<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.954      0.956      0.977      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      2.98G     0.6621     0.4649     0.9808         50        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.952      0.957      0.977      0.874
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      2.98G     0.6647     0.4665     0.9824         57        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.955      0.953      0.977      0.875
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      2.98G     0.6623      0.464     0.9787         70        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:44<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.9it/s 4.1s0.1s
#                    all        883       2324      0.956      0.955      0.978      0.875
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      2.98G      0.659     0.4596     0.9799         42        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.952      0.957      0.978      0.875
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      2.98G     0.6585     0.4532     0.9774         39        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.1it/s 3.9s0.1s
#                    all        883       2324      0.952      0.956      0.978      0.875
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      2.98G     0.6577     0.4563     0.9808         41        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:46<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.4it/s 4.4s0.1s
#                    all        883       2324      0.953      0.956      0.979      0.876
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      2.98G     0.6485      0.447     0.9744         44        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:44<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.9it/s 4.1s0.1s
#                    all        883       2324      0.953      0.957      0.978      0.876
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      2.98G     0.6518     0.4461     0.9766         73        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:42<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.6it/s 4.2s0.1s
#                    all        883       2324      0.953      0.957      0.978      0.877
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      2.98G     0.6504      0.443     0.9741         51        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.953      0.956      0.979      0.878
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      2.98G     0.6479     0.4408      0.971         55        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:44<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.8it/s 4.1s0.1s
#                    all        883       2324      0.953      0.956      0.979      0.879
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      2.98G      0.648     0.4406     0.9752         74        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:44<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.9it/s 4.1s0.1s
#                    all        883       2324      0.953      0.956      0.979      0.878
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      2.98G     0.6436     0.4381     0.9705         52        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:42<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.8it/s 4.1s0.1s
#                    all        883       2324      0.953      0.955      0.979      0.879
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      2.99G     0.6419     0.4326     0.9717         54        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:42<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.5it/s 4.3s0.2s
#                    all        883       2324      0.954      0.955      0.979       0.88
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      2.99G     0.6371     0.4275     0.9698         34        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:43<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.9it/s 4.0s0.1s
#                    all        883       2324      0.954      0.955      0.979      0.879
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      3.41G     0.6321     0.4292     0.9688         63        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:44<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.8it/s 4.1s0.1s
#                    all        883       2324      0.954      0.954      0.979      0.879
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100       3.1G     0.6323     0.4229     0.9656         63        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:42<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.7it/s 4.2s0.2s
#                    all        883       2324      0.957      0.953      0.979       0.88
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      2.78G     0.6302     0.4226     0.9673        104        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:46<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 5.5it/s 5.1s0.2s
#                    all        883       2324      0.957      0.953      0.979       0.88
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      2.78G      0.626     0.4182     0.9654         54        640: 100% ━━━━━━━━━━━━ 1018/1018 5.7it/s 2:57<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 5.7it/s 5.0s0.2s
#                    all        883       2324      0.957      0.952      0.979       0.88
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      2.78G     0.6292     0.4187     0.9654         40        640: 100% ━━━━━━━━━━━━ 1018/1018 5.7it/s 2:59<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 5.8it/s 4.8s0.2s
#                    all        883       2324      0.958      0.953      0.979       0.88
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      2.78G     0.6236     0.4131     0.9653         75        640: 100% ━━━━━━━━━━━━ 1018/1018 6.0it/s 2:51<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.7it/s 4.2s0.1s
#                    all        883       2324      0.957      0.953      0.979       0.88
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      3.09G     0.6244     0.4125     0.9634         60        640: 100% ━━━━━━━━━━━━ 1018/1018 6.3it/s 2:43<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.7it/s 4.2s0.1s
#                    all        883       2324      0.958      0.953      0.979      0.881
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      2.76G      0.623     0.4078     0.9632         43        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.8it/s 4.1s0.2s
#                    all        883       2324      0.959      0.951      0.979      0.881
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      3.06G     0.6176     0.4069     0.9614         38        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:44<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.8it/s 4.1s0.1s
#                    all        883       2324      0.959      0.951      0.979      0.882
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      2.82G      0.625     0.4074     0.9643         52        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.9it/s 4.1s0.1s
#                    all        883       2324       0.96       0.95      0.978      0.882
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      2.82G      0.614        0.4     0.9587         46        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.9it/s 4.1s0.1s
#                    all        883       2324      0.959      0.952      0.979      0.881
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      3.14G     0.6146     0.3995     0.9584         44        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.7it/s 4.2s0.1s
#                    all        883       2324      0.959      0.952      0.979      0.882
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      3.06G     0.6086     0.3935     0.9573         94        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.1it/s 4.6s0.1s
#                    all        883       2324       0.96      0.952      0.979      0.882
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      2.56G     0.6047     0.3917     0.9552         49        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.6it/s 4.3s0.1s
#                    all        883       2324       0.96      0.952      0.979      0.881
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      3.09G     0.6133     0.3917     0.9567         29        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.7it/s 4.2s0.1s
#                    all        883       2324      0.961      0.952      0.979      0.882
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      2.97G     0.5994     0.3877     0.9526         87        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 7.0it/s 4.0s0.1s
#                    all        883       2324      0.961      0.952      0.979      0.882
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      2.97G     0.6066      0.387     0.9547         97        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.8it/s 4.1s0.1s
#                    all        883       2324      0.962      0.952      0.979      0.882
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      2.97G     0.5979     0.3813     0.9524         55        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.9it/s 4.1s0.1s
#                    all        883       2324       0.96      0.952      0.979      0.882
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      2.97G     0.5943     0.3794     0.9524         95        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.7it/s 4.2s0.1s
#                    all        883       2324      0.961      0.953      0.979      0.882
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      2.97G     0.5985     0.3794     0.9516         39        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:46<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.7it/s 4.2s0.1s
#                    all        883       2324       0.96      0.953      0.979      0.883
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      2.97G     0.5985     0.3798      0.951        182        640: 100% ━━━━━━━━━━━━ 1018/1018 6.1it/s 2:46<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.8it/s 4.1s0.1s
#                    all        883       2324      0.961      0.954      0.979      0.883
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      2.97G     0.5868     0.3698     0.9495         51        640: 100% ━━━━━━━━━━━━ 1018/1018 5.9it/s 2:52<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.6it/s 4.2s0.1s
#                    all        883       2324       0.96      0.955      0.979      0.883
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      2.97G      0.512     0.2939     0.8972        127        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 5.7it/s 4.9s0.2s
#                    all        883       2324       0.96      0.956      0.979      0.883
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      2.97G     0.5088     0.2908     0.8965         15        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.1it/s 4.6s0.2s
#                    all        883       2324       0.96      0.956      0.979      0.883
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      2.97G     0.5038     0.2867     0.8925         16        640: 100% ━━━━━━━━━━━━ 1018/1018 6.1it/s 2:46<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 4.7it/s 6.0s0.3s
#                    all        883       2324      0.961      0.957       0.98      0.884
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      2.97G     0.5016     0.2833     0.8901         32        640: 100% ━━━━━━━━━━━━ 1018/1018 5.5it/s 3:05<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 4.6it/s 6.1s0.2s
#                    all        883       2324      0.962      0.957       0.98      0.884
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      2.97G      0.496     0.2796     0.8866         67        640: 100% ━━━━━━━━━━━━ 1018/1018 5.4it/s 3:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 4.6it/s 6.1s0.2s
#                    all        883       2324       0.96      0.959       0.98      0.884
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      2.97G     0.4948     0.2763     0.8877         20        640: 100% ━━━━━━━━━━━━ 1018/1018 5.6it/s 3:03<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 4.8it/s 5.8s0.2s
#                    all        883       2324       0.96      0.959       0.98      0.884
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      2.97G     0.4886     0.2713      0.886         28        640: 100% ━━━━━━━━━━━━ 1018/1018 6.0it/s 2:49<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.3it/s 4.5s0.2s
#                    all        883       2324      0.961      0.959      0.981      0.884
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      2.98G     0.4893       0.27     0.8866         66        640: 100% ━━━━━━━━━━━━ 1018/1018 5.6it/s 3:01<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 4.6it/s 6.1s0.2s
#                    all        883       2324      0.961      0.959       0.98      0.884
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      2.98G     0.4853     0.2683     0.8848         23        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.4it/s 4.4s0.2s
#                    all        883       2324      0.961      0.959       0.98      0.884
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      2.98G     0.4807     0.2637     0.8835         15        640: 100% ━━━━━━━━━━━━ 1018/1018 6.2it/s 2:45<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 6.5it/s 4.3s0.1s
#                    all        883       2324      0.961       0.96       0.98      0.884
#
# 100 epochs completed in 4.767 hours.
# Optimizer stripped from C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train\weights\last.pt, 5.5MB
# Optimizer stripped from C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train\weights\best.pt, 5.5MB
#
# Validating C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train\weights\best.pt...
# Ultralytics 8.3.207  Python-3.13.7 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# YOLO11n summary (fused): 100 layers, 2,588,782 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 28/28 5.6it/s 5.0s0.2s
#                    all        883       2324      0.961       0.96       0.98      0.884
#         coffee_nescafe         20        135      0.839      0.844      0.898      0.729
#          coffee_kopiko         36        181      0.963      0.875      0.977      0.864
# Lucky-Me-Pancit-Canton         25         40      0.968      0.975      0.993       0.93
#            Coke-in-can         25         35      0.991          1      0.995      0.985
#            Alaska-Milk         25         69      0.957          1      0.995      0.827
#           Century-Tuna         25        440      0.928      0.967      0.984      0.829
#    VCut-Spicy-Barbeque         25         66      0.962       0.97      0.991       0.92
#       Selecta-Cornetto         25         25          1      0.991      0.995      0.789
#          Nestle-Yogurt         25         28      0.984      0.964      0.973      0.908
#  Femme-Bathroom-Tissue         25         36      0.965          1      0.989      0.929
#        Maya-Champorado         29         38      0.939          1      0.994      0.911
#       JnJ-Potato-Chips         25         25      0.988          1      0.995      0.918
#        Nivea-Deodorant         25         48      0.893      0.874      0.938      0.712
#    UFC-Canned-Mushroom         26         52      0.987          1      0.995      0.891
# Libbys-Vienna-Sausage-can         26         53      0.904      0.886      0.924       0.77
#                 Stik-O         25         35       0.97          1      0.995      0.944
#       NissinCupNoodles         25        237      0.952      0.667      0.914      0.638
#    Dewberry-Strawberry         25         48      0.878      0.938      0.957      0.908
#                Smart-C         50         58          1      0.983      0.995      0.977
#    Pineapple-juice-can         25         25      0.989          1      0.995      0.879
#         Nestle-Chuckie         25         26      0.988          1      0.995      0.995
# Delight-Probiotic-Drink         25         25          1      0.986      0.995      0.985
#  Summit-Drinking-Water         25         49      0.994          1      0.995      0.951
#            almond_milk         25         25          1      0.993      0.995      0.923
#                 Piknik         26         77      0.886      0.935       0.98      0.922
#               Rambutan         25         40      0.943      0.831      0.939      0.705
#             HS-Shampoo         25         36      0.994          1      0.995      0.914
#      irish-spring-soap         25         25      0.962          1      0.995      0.965
#            c2_na_green         25         35      0.985          1      0.995      0.951
#     colgate_toothpaste         25         38      0.992          1      0.995       0.98
#           555-sardines         25        161      0.904          1      0.978      0.803
#        meadows-truffle         25         52      0.981      0.978      0.994      0.896
#           double-black         27         28      0.991          1      0.995      0.905
#     NongshimCupNoodles         25         33      0.994       0.97      0.994        0.9
# Speed: 0.2ms preprocess, 1.8ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train
# MLflow: results logged to runs\mlflow
# MLflow: disable with 'yolo settings mlflow=False'
# Training completed successfully!
# Results saved to: C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train
# Best model weights: C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train/weights/best.pt
# Last model weights: C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train/weights/last.pt

# %%
# Copilot prompt:
# After training, evaluate the YOLO model on the test dataset.
# Print metrics such as mAP50, mAP50-95, precision, recall, and overall accuracy.

if 'training_results' in locals() and training_results is not None:
    try:
        # Load the best trained model
        best_model_path = f"{training_results.save_dir}/weights/best.pt"
        trained_model = YOLO(best_model_path)
        
        print("Evaluating the trained model on test dataset...")
        
        # Evaluate on test dataset
        eval_results = trained_model.val(data=f"{dataset_path}/data.yaml")
        
        print("\n" + "="*50)
        print("MODEL EVALUATION RESULTS")
        print("="*50)
        
        # Extract and print key metrics
        if hasattr(eval_results, 'box'):
            metrics = eval_results.box
            print(f"mAP50 (IoU=0.5): {metrics.map50:.4f}")
            print(f"mAP50-95 (IoU=0.5:0.95): {metrics.map:.4f}")
            print(f"Precision: {metrics.mp:.4f}")
            print(f"Recall: {metrics.mr:.4f}")
            
        # Print class-wise metrics if available
        if hasattr(eval_results, 'box') and hasattr(eval_results.box, 'ap_class_index'):
            ap_class_index = eval_results.box.ap_class_index
            if len(ap_class_index) > 0:
                print("\nClass-wise mAP50:")
                # Get the mAP values per class
                maps = eval_results.box.maps  # This gives mAP50 per class
                for i, class_idx in enumerate(ap_class_index):
                    class_name = class_names[class_idx] if class_idx < len(class_names) else f'class_{class_idx}'
                    if i < len(maps):
                        print(f"  {class_name}: {maps[i]:.4f}")
                    else:
                        print(f"  {class_name}: N/A")
        
        print(f"\nEvaluation completed!")
        print(f"Results saved to: {eval_results.save_dir}")
        
    except Exception as e:
        print(f"Evaluation failed: {str(e)}")
        print("Please ensure training was completed successfully.")
        
else:
    print("No trained model found. Please complete training first.")
    print("If you have a pre-trained model, load it using:")
    print("trained_model = YOLO('path/to/your/model.pt')")
# Out:
# Evaluating the trained model on test dataset...
# Ultralytics 8.3.207  Python-3.13.7 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# YOLO11n summary (fused): 100 layers, 2,588,782 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 301.5150.6 MB/s, size: 35.0 KB)
# val: Scanning C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\data\mp4\dataset\test\labels.cache... 883 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 883/883 1.2Mit/s 0.0s0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 56/56 10.9it/s 5.2s0.2s
#                    all        883       2324      0.961      0.959       0.98      0.885
#         coffee_nescafe         20        135       0.84      0.844      0.899      0.732
#          coffee_kopiko         36        181      0.961      0.873      0.977      0.863
# Lucky-Me-Pancit-Canton         25         40      0.968      0.975      0.994      0.933
#            Coke-in-can         25         35      0.991          1      0.995      0.982
#            Alaska-Milk         25         69      0.957          1      0.995      0.828
#           Century-Tuna         25        440      0.928      0.967      0.984      0.831
#    VCut-Spicy-Barbeque         25         66      0.962       0.97      0.991      0.918
#       Selecta-Cornetto         25         25          1      0.991      0.995      0.789
#          Nestle-Yogurt         25         28      0.984      0.964      0.973      0.906
#  Femme-Bathroom-Tissue         25         36      0.965          1      0.989      0.935
#        Maya-Champorado         29         38      0.939          1      0.994      0.911
#       JnJ-Potato-Chips         25         25      0.988          1      0.995      0.924
#        Nivea-Deodorant         25         48      0.893      0.872      0.938      0.714
#    UFC-Canned-Mushroom         26         52      0.987          1      0.995      0.888
# Libbys-Vienna-Sausage-can         26         53      0.904      0.886      0.924      0.771
#                 Stik-O         25         35       0.97          1      0.995      0.946
#       NissinCupNoodles         25        237      0.952      0.668      0.914      0.637
#    Dewberry-Strawberry         25         48      0.878      0.938      0.957      0.908
#                Smart-C         50         58          1      0.983      0.995      0.977
#    Pineapple-juice-can         25         25      0.989          1      0.995      0.879
#         Nestle-Chuckie         25         26      0.988          1      0.995      0.995
# Delight-Probiotic-Drink         25         25          1      0.986      0.995      0.985
#  Summit-Drinking-Water         25         49      0.994          1      0.995      0.948
#            almond_milk         25         25          1      0.993      0.995      0.929
#                 Piknik         26         77      0.886      0.935       0.98      0.919
#               Rambutan         25         40      0.943      0.831      0.939      0.711
#             HS-Shampoo         25         36      0.994          1      0.995      0.916
#      irish-spring-soap         25         25      0.962          1      0.995       0.97
#            c2_na_green         25         35      0.982          1      0.995      0.951
#     colgate_toothpaste         25         38      0.992          1      0.995      0.983
#           555-sardines         25        161      0.904          1      0.978      0.802
#        meadows-truffle         25         52      0.981      0.978      0.994      0.895
#           double-black         27         28      0.991          1      0.995      0.905
#     NongshimCupNoodles         25         33      0.994       0.97      0.994        0.9
# Speed: 0.3ms preprocess, 2.9ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\runs\detect\val9
#
# ==================================================
# MODEL EVALUATION RESULTS
# ==================================================
# mAP50 (IoU=0.5): 0.9804
# mAP50-95 (IoU=0.5:0.95): 0.8848
# Precision: 0.9608
# Recall: 0.9595
#
# Class-wise mAP50:
#   coffee_nescafe: 0.7324
#   coffee_kopiko: 0.8634
#   lucky-me-pancit-canton: 0.9325
#   Coke-in-can: 0.9825
#   alaska_milk: 0.8283
#   Century-Tuna: 0.8314
#   VCut-Spicy-Barbeque: 0.9180
#   Selecta-Cornetto: 0.7894
#   nestleyogurt: 0.9057
#   Femme-Bathroom-Tissue: 0.9349
#   maya-champorado: 0.9113
#   jnj-potato-chips: 0.9242
#   Nivea-Deodorant: 0.7143
#   UFC-Canned-Mushroom: 0.8885
#   Libbys-Vienna-Sausage-can: 0.7708
#   Stik-O: 0.9457
#   nissin_cup_noodles: 0.6370
#   dewberry-strawberry: 0.9081
#   Smart-C: 0.9771
#   pineapple-juice-can: 0.8794
#   nestle_chuckie: 0.9950
#   Delight-Probiotic-Drink: 0.9851
#   Summit-Drinking-Water: 0.9482
#   almond_milk: 0.9291
#   Piknik: 0.9187
#   Rambutan: 0.7115
#   head&shoulders_shampoo: 0.9156
#   irish-spring-soap: 0.9697
#   c2_na_green: 0.9510
#   colgate_toothpaste: 0.9833
#   555-sardines-tomato: 0.8015
#   meadows_truffle_chips: 0.8951
#   double-black: 0.9045
#   NongshimCupNoodles: 0.8997
#
# Evaluation completed!
# Results saved to: C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\runs\detect\val9

# %%
# Copilot prompt:
# Plot YOLO training results including loss curves and mAP using matplotlib from the results file.

if 'training_results' in locals() and training_results is not None:
    try:
        # Path to training results
        results_dir = training_results.save_dir
        results_csv = f"{results_dir}/results.csv"
        
        # Check if results.csv exists
        if os.path.exists(results_csv):
            import pandas as pd
            
            # Read training results
            df = pd.read_csv(results_csv)
            # Clean column names by removing whitespace
            df.columns = df.columns.str.strip()
            
            # Create subplots for different metrics
            fig, axes = plt.subplots(2, 2, figsize=(15, 10))
            
            # Plot training and validation losses
            if 'train/box_loss' in df.columns:
                axes[0, 0].plot(df['epoch'], df['train/box_loss'], label='Train Box Loss', color='blue')
                axes[0, 0].plot(df['epoch'], df['val/box_loss'], label='Val Box Loss', color='red')
                axes[0, 0].set_title('Box Loss')
                axes[0, 0].set_xlabel('Epoch')
                axes[0, 0].set_ylabel('Loss')
                axes[0, 0].legend()
                axes[0, 0].grid(True)
            
            # Plot objectness loss
            if 'train/cls_loss' in df.columns:
                axes[0, 1].plot(df['epoch'], df['train/cls_loss'], label='Train Cls Loss', color='blue')
                axes[0, 1].plot(df['epoch'], df['val/cls_loss'], label='Val Cls Loss', color='red')
                axes[0, 1].set_title('Class Loss')
                axes[0, 1].set_xlabel('Epoch')
                axes[0, 1].set_ylabel('Loss')
                axes[0, 1].legend()
                axes[0, 1].grid(True)
            
            # Plot mAP scores
            if 'metrics/mAP50(B)' in df.columns:
                axes[1, 0].plot(df['epoch'], df['metrics/mAP50(B)'], label='mAP@0.5', color='green')
                if 'metrics/mAP50-95(B)' in df.columns:
                    axes[1, 0].plot(df['epoch'], df['metrics/mAP50-95(B)'], label='mAP@0.5:0.95', color='orange')
                axes[1, 0].set_title('Mean Average Precision (mAP)')
                axes[1, 0].set_xlabel('Epoch')
                axes[1, 0].set_ylabel('mAP')
                axes[1, 0].legend()
                axes[1, 0].grid(True)
            
            # Plot precision and recall
            if 'metrics/precision(B)' in df.columns and 'metrics/recall(B)' in df.columns:
                axes[1, 1].plot(df['epoch'], df['metrics/precision(B)'], label='Precision', color='purple')
                axes[1, 1].plot(df['epoch'], df['metrics/recall(B)'], label='Recall', color='brown')
                axes[1, 1].set_title('Precision and Recall')
                axes[1, 1].set_xlabel('Epoch')
                axes[1, 1].set_ylabel('Score')
                axes[1, 1].legend()
                axes[1, 1].grid(True)
            
            plt.tight_layout()
            plt.suptitle('YOLO Training Results', y=1.02, fontsize=16)
            plt.show()
            
            # Print final training statistics
            print("\nFinal Training Statistics:")
            print("-" * 40)
            final_epoch = df.iloc[-1]
            if 'metrics/mAP50' in df.columns:
                print(f"Final mAP@0.5: {final_epoch['metrics/mAP50']:.4f}")
            if 'metrics/mAP50-95' in df.columns:
                print(f"Final mAP@0.5:0.95: {final_epoch['metrics/mAP50-95']:.4f}")
            if 'metrics/precision' in df.columns:
                print(f"Final Precision: {final_epoch['metrics/precision']:.4f}")
            if 'metrics/recall' in df.columns:
                print(f"Final Recall: {final_epoch['metrics/recall']:.4f}")
                
        else:
            print(f"Results file not found at: {results_csv}")
            print("Training may not have completed or results file may be in a different location.")
            
    except Exception as e:
        print(f"Error plotting training results: {str(e)}")
        print("Make sure pandas is installed: pip install pandas")
        
else:
    print("No training results found. Please complete training first.")
# Out:
# Final Training Statistics:
# ----------------------------------------

# %%
# Copilot prompt:
# Load several test images and run inference using the trained model.
# Display predicted bounding boxes, class names, and confidence scores.

if 'trained_model' in locals() and trained_model is not None:
    try:
        # Path to test images
        test_images_path = f"{dataset_path}/test/images"
        
        if os.path.exists(test_images_path) and os.listdir(test_images_path):
            image_files = [f for f in os.listdir(test_images_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
            
            if image_files:
                # Select random test images
                num_images = min(4, len(image_files))
                random_test_images = random.sample(image_files, num_images)
                
                fig, axes = plt.subplots(2, 2, figsize=(15, 12))
                axes = axes.flatten()
                
                for i, img_file in enumerate(random_test_images):
                    img_path = os.path.join(test_images_path, img_file)
                    
                    # Run inference
                    results = trained_model.predict(img_path, conf=0.25, verbose=False)
                    
                    # Process results
                    if results and len(results) > 0:
                        result = results[0]
                        
                     
                        # Draw predictions
                        plotted_image = cv2.cvtColor(result.plot(), cv2.COLOR_BGR2RGB)
                       
                    # Display image
                    axes[i].imshow(plotted_image)
                    axes[i].set_title(f'Test Image: {img_file}')
                    axes[i].axis('off')
                
                plt.tight_layout()
                plt.suptitle('YOLO Inference Results on Test Images', y=1.02, fontsize=16)
                plt.show()
                
                print(f"Inference completed on {num_images} test images.")
                
            else:
                print("No image files found in test directory.")
        else:
            print("Test images directory not found or empty.")
            print("Please add test images to run inference.")
            
    except Exception as e:
        print(f"Inference failed: {str(e)}")
        
else:
    print("No trained model available. Please complete training and evaluation first.")
    print("Or load a trained model: trained_model = YOLO('path/to/model.pt')")
# Out:
# Inference completed on 4 test images.

# %%
# Copilot prompt:
# Export the trained YOLO model to ONNX or TorchScript format for easier deployment if needed.

if 'trained_model' in locals() and trained_model is not None:
    try:
        print("Exporting trained model to different formats...")
        
        # Export to ONNX format
        print("Exporting to ONNX format...")
        onnx_path = trained_model.export(format='onnx', imgsz=640, dynamic=False)
        print(f"ONNX model exported to: {onnx_path}")
        
        # # Export to TorchScript format
        # print("Exporting to TorchScript format...")
        # torchscript_path = trained_model.export(format='torchscript', imgsz=640)
        # print(f"TorchScript model exported to: {torchscript_path}")
        
        # # Export to TensorRT format (if available)
        # try:
        #     print("Attempting to export to TensorRT format...")
        #     tensorrt_path = trained_model.export(format='engine', imgsz=640)
        #     print(f"TensorRT model exported to: {tensorrt_path}")
        # except Exception as e:
        #     print(f"TensorRT export failed (this is normal if TensorRT is not installed): {str(e)}")
        
        # # Export to CoreML format (for Apple devices)
        # try:
        #     print("Attempting to export to CoreML format...")
        #     coreml_path = trained_model.export(format='coreml', imgsz=640)
        #     print(f"CoreML model exported to: {coreml_path}")
        # except Exception as e:
        #     print(f"CoreML export failed (this is normal if coremltools is not installed): {str(e)}")
        
        print("\nModel export completed!")
        print("Available formats:")
        print("- ONNX: Best for general deployment and cross-platform inference")
        print("- TorchScript: Good for PyTorch-based production environments")
        print("- TensorRT: Optimized for NVIDIA GPUs (if available)")
        print("- CoreML: Optimized for Apple devices (if available)")
        
    except Exception as e:
        print(f"Model export failed: {str(e)}")
        print("Make sure the model was trained successfully.")
        
else:
    print("No trained model available for export.")
    print("Please complete training first or load a trained model:")
# Out:
# Exporting trained model to different formats...
# Exporting to ONNX format...
# Ultralytics 8.3.207  Python-3.13.7 torch-2.8.0+cu128 CPU (Intel Core i5-14450HX)
#
# PyTorch: starting from 'C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 38, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.19.0 opset 22...
#
# PyTorch: starting from 'C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 38, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.19.0 opset 22...
# ONNX: slimming with onnxslim 0.1.71...
# ONNX: slimming with onnxslim 0.1.71...
# ONNX: export success  0.7s, saved as 'C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train\weights\best.onnx' (10.1 MB)
#
# Export complete (0.9s)
# Results saved to C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train\weights
# Predict:         yolo predict task=detect model=C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train\weights\best.onnx imgsz=640 data=.././data/mp4/dataset/data.yaml
# Visualize:       https://netron.app
# ONNX model exported to: C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train\weights\best.onnx
#
# Model export completed!
# Available formats:
# - ONNX: Best for general deployment and cross-platform inference
# - TorchScript: Good for PyTorch-based production environments
# - TensorRT: Optimized for NVIDIA GPUs (if available)
# - CoreML: Optimized for Apple devices (if available)
# ONNX: export success  0.7s, saved as 'C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train\weights\best.onnx' (10.1 MB)
#
# Export complete (0.9s)
# Results saved to C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train\weights
# Predict:         yolo predict task=detect model=C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train\weights\best.onnx imgsz=640 data=.././data/mp4/dataset/data.yaml
# Visualize:       https://netron.app
# ONNX model exported to: C:\Users\jhon\Desktop\Coding\AI\AI231-machine-problems\MP4_YOLO_TEST2\YOLO11N\train\weights\best.onnx
#
# Model export completed!
# Available formats:
# - ONNX: Best for general deployment and cross-platform inference
# - TorchScript: Good for PyTorch-based production environments
# - TensorRT: Optimized for NVIDIA GPUs (if available)
# - CoreML: Optimized for Apple devices (if available)

# %%
# Copilot prompt:
# Build a Gradio app that loads the trained YOLO model and allows users to upload or capture an image.
# The app should return the image with detected bounding boxes and labels drawn on it.
import os

def load_yolo_model():
    model_path = './YOLO11N/train/weights/best.pt'
    if not os.path.exists(model_path):
        raise FileNotFoundError(f"Model file not found at {model_path}")
    return YOLO(model_path)

# Load model when your app starts
try:
    inference_model = load_yolo_model().to(device)
    print("YOLO model loaded successfully")
except Exception as e:
    print(f"Failed to load YOLO model: {e}")
    inference_model = None

    
def yolo_inference(image):
    if inference_model is None:
        return image, "Error: YOLO model not loaded"
    
    if image is None:
        return None, "No image captured"
    
    try:
        # Run inference
        results = inference_model.predict(image, conf=0.25, verbose=False)
        
        if results and len(results) > 0:
            result = results[0]
            plotted_image = cv2.cvtColor(result.plot(), cv2.COLOR_BGR2RGB)
            # result_image = Image.fromarray(plotted_image[..., ::-1])
            
            if result.boxes is not None and len(result.boxes) > 0:
                detection_info = f"Detected {len(result.boxes)} objects"
            else:
                detection_info = "No objects detected"
                
            return plotted_image, detection_info
        else:
            return image, "No detection results"
            
    except Exception as e:
        return image, f"Error during inference: {str(e)}"
        

# Create Gradio interface with live camera support
def create_gradio_app():
    """Create and return Gradio interface with live camera functionality"""
    
    # Interface description
    description = """
    # AI231 MP4 Object Detection App
    
    **Model:** YOLOv11n trained on MP4 dataset (34 classes) with 100 epochs

    **Multiple Detection Modes:**
    - **Image Upload**: Upload an image file for object detection
    - **Live Camera**: Use your webcam or phone camera for real-time detection
    - **Webcam Capture**: Take a snapshot from your camera for detection
    
    **Features:**
    - Real-time object detection with bounding boxes
    - Class labels and confidence scores
    - Support for webcam and mobile camera access
    - Works on PC, laptop, and mobile devices
    """
    
    # Create tabbed interface for different input methods
    with gr.Blocks(theme=gr.themes.Soft(), title="AI231 MP4 Object Detection") as demo:
        gr.Markdown("# 🎯 AI231 MP4 Object Detection System")
        gr.Markdown(description)
        
        with gr.Tabs():
            # Tab 1: Image Upload
            with gr.Tab("📁 Upload Image"):
                with gr.Row():
                    with gr.Column():
                        upload_input = gr.Image(
                            label="Upload Image", 
                            type="pil",
                            height=400
                        )
                        upload_btn = gr.Button("🔍 Detect Objects", variant="primary")
                    
                    with gr.Column():
                        upload_output = gr.Image(
                            label="Detection Results", 
                            type="pil",
                            height=400
                        )
                        upload_info = gr.Textbox(
                            label="Detection Info",
                            lines=3
                        )
                upload_btn.click(
                    fn=yolo_inference,
                    inputs=[upload_input],
                    outputs=[upload_output, upload_info]
                )
            
            # Tab 2: Live Camera (Real-time)
            with gr.Tab("📹 Live Camera"):
                with gr.Row():
                    with gr.Column():
                        live_input = gr.Image(
                            label="Live Camera Feed",
                            sources=["webcam"],
                            type="pil",
                            height=400,
                            streaming=True  # Enable live streaming
                        )
                    
                    with gr.Column():
                        live_output = gr.Image(
                            label="Live Detection Results",
                            type="pil",
                            height=400
                        )
                        live_info = gr.Textbox(
                            label="Live Detection Info",
                            lines=3
                        )
                
                # Real-time detection on camera input
                live_input.stream(
                    fn=yolo_inference,
                    inputs=[live_input],
                    outputs=[live_output, live_info],
                    show_progress=False,  # Disable progress bar for smoother experience
                    time_limit=10
                )
            
            # Tab 3: Camera Capture (Snapshot)
            with gr.Tab("📸 Camera Capture"):
                with gr.Row():
                    with gr.Column():
                        capture_input = gr.Image(
                            label="Camera Capture",
                            sources=["webcam"],
                            type="pil",
                            height=400
                        )
                        capture_btn = gr.Button("📸 Capture & Detect", variant="primary")
                    
                    with gr.Column():
                        capture_output = gr.Image(
                            label="Capture Detection Results",
                            type="pil",
                            height=400
                        )
                        capture_info = gr.Textbox(
                            label="Capture Detection Info",
                            lines=3
                        )
                
                capture_btn.click(
                    fn=yolo_inference,
                    inputs=[capture_input],
                    outputs=[capture_output, capture_info]
                )
        
        # Add usage instructions
        with gr.Accordion("📋 Usage Instructions", open=False):
            gr.Markdown("""
            ### How to Use:
            
            **Image Upload Tab:**
            - Click "Choose File" to upload an image
            - Click "Detect Objects" to analyze the image
            
            **Live Camera Tab:**
            - Allow camera permissions when prompted
            - Point your camera at objects for real-time detection
            - Detection happens automatically as you move the camera
            
            **Camera Capture Tab:**
            - Allow camera permissions when prompted  
            - Position your camera and click "Capture & Detect"
            - Perfect for taking snapshots for analysis
            
            ### Tips:
            - Ensure good lighting for better detection accuracy
            - Keep objects clearly visible in the camera frame
            - The model detects 34 different product categories
            - Confidence threshold is set to 0.25 (25%)
            """)
    
    return demo

# Create the Gradio app
print("Creating Gradio app...")
gradio_app = create_gradio_app()
print("Gradio app created successfully!")
# Out:
# YOLO model loaded successfully
# Creating Gradio app...
# Gradio app created successfully!

# %%
# Copilot prompt:
# Launch the Gradio demo interface with share=True so that it can be accessed externally.

if 'gradio_app' in locals():
    try:
        print("Launching Gradio interface...")
        print("The interface will be available locally and with a public share link.")
        print("Note: In some environments, you may need to adjust firewall settings.")
        
        # Launch the Gradio app with sharing enabled
        gradio_app.launch(
            share=True,           # Create a public share link
            server_name="0.0.0.0", # Allow external connections
            server_port=7860,     # Default Gradio port
            show_error=True,      # Show errors in the interface
            debug=True,           # Enable debug mode
            inbrowser=True        # Automatically open in browser
        )
        
    except Exception as e:
        print(f"Failed to launch Gradio app: {str(e)}")
        print("Try launching without share: gradio_app.launch(share=False)")
        
        # Fallback: launch without sharing
        try:
            print("Attempting to launch without sharing...")
            gradio_app.launch(share=False, inbrowser=True)
        except Exception as e2:
            print(f"Gradio launch failed completely: {str(e2)}")
            print("Make sure Gradio is properly installed: pip install gradio")
            
else:
    print("Gradio app not found. Please run the previous cell to create the app first.")
# Out:
# Launching Gradio interface...
# The interface will be available locally and with a public share link.
# Note: In some environments, you may need to adjust firewall settings.
# Failed to launch Gradio app: Cannot find empty port in range: 7860-7860. You can specify a different port by setting the GRADIO_SERVER_PORT environment variable or passing the `server_port` parameter to `launch()`.
# Try launching without share: gradio_app.launch(share=False)
# Attempting to launch without sharing...
# * Running on local URL:  http://127.0.0.1:7872
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7872/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# Once you complete the prompts above:
#
# YOLOv11 or YOLOv8 model is trained on your dataset.
#
# Evaluation metrics printed: mAP50, mAP50-95, precision, recall.
#
# Bounding box results displayed for visual verification.
#
# Gradio app allows live or uploaded image inference.
#
# All code reproducible in a Colab link for submission.
